# %% [markdown]
# <a href="https://colab.research.google.com/github/DavidB363/file-store/blob/master/Lab4/bank_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('https://raw.githubusercontent.com/albanda/CE888/master/lab4/bank-additional-full.csv', delimiter = ";")

df.head()
# Out:
#    age        job  marital  ... euribor3m nr.employed   y
# 0   56  housemaid  married  ...     4.857      5191.0  no
# 1   57   services  married  ...     4.857      5191.0  no
# 2   37   services  married  ...     4.857      5191.0  no
# 3   40     admin.  married  ...     4.857      5191.0  no
# 4   56   services  married  ...     4.857      5191.0  no
#
# [5 rows x 21 columns]

# %%
df_dummies = pd.get_dummies(df)
df_dummies
# Out:
#        age  duration  campaign  ...  poutcome_success  y_no  y_yes
# 0       56       261         1  ...                 0     1      0
# 1       57       149         1  ...                 0     1      0
# 2       37       226         1  ...                 0     1      0
# 3       40       151         1  ...                 0     1      0
# 4       56       307         1  ...                 0     1      0
# ...    ...       ...       ...  ...               ...   ...    ...
# 41183   73       334         1  ...                 0     0      1
# 41184   46       383         1  ...                 0     1      0
# 41185   56       189         2  ...                 0     1      0
# 41186   44       442         1  ...                 0     0      1
# 41187   74       239         3  ...                 0     1      0
#
# [41188 rows x 65 columns]

# %%
del df_dummies["y_no"]
del df_dummies["duration"]

# %%
df_dummies
# Out:
#        age  campaign  pdays  ...  poutcome_nonexistent  poutcome_success  y_yes
# 0       56         1    999  ...                     1                 0      0
# 1       57         1    999  ...                     1                 0      0
# 2       37         1    999  ...                     1                 0      0
# 3       40         1    999  ...                     1                 0      0
# 4       56         1    999  ...                     1                 0      0
# ...    ...       ...    ...  ...                   ...               ...    ...
# 41183   73         1    999  ...                     1                 0      1
# 41184   46         1    999  ...                     1                 0      0
# 41185   56         2    999  ...                     1                 0      0
# 41186   44         1    999  ...                     1                 0      1
# 41187   74         3    999  ...                     0                 0      0
#
# [41188 rows x 63 columns]

# %%
df_dummies['y_yes'].plot.hist()

# %%
X_df=df_dummies.iloc[:, :-1]
X_df
# Out:
#        age  campaign  ...  poutcome_nonexistent  poutcome_success
# 0       56         1  ...                     1                 0
# 1       57         1  ...                     1                 0
# 2       37         1  ...                     1                 0
# 3       40         1  ...                     1                 0
# 4       56         1  ...                     1                 0
# ...    ...       ...  ...                   ...               ...
# 41183   73         1  ...                     1                 0
# 41184   46         1  ...                     1                 0
# 41185   56         2  ...                     1                 0
# 41186   44         1  ...                     1                 0
# 41187   74         3  ...                     0                 0
#
# [41188 rows x 62 columns]

# %%
y_df=df_dummies.iloc[:, -1]
y_df
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 41183    1
# 41184    0
# 41185    0
# 41186    1
# 41187    0
# Name: y_yes, Length: 41188, dtype: uint8

# %%
# Convert dataframes to arrays.
X=X_df.values
y=y_df.values

# %%
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import StratifiedKFold, KFold

clf = ExtraTreesClassifier(n_estimators=100, max_depth=4)
skf = StratifiedKFold(n_splits=10)
score=[]
for train, test in skf.split(X_df, y_df):
  #print('train -  {}   |   test -  {}'.format(np.bincount(y_df[train]), np.bincount(y_df[test])))
  clf.fit(X[train],y[train])
  score.append(clf.score(X[test],y[test]))
  y_pred=clf.predict(X[test])
print(score)
print('Average accuracy', np.mean(score))
# Out:
# [0.8873512988589464, 0.8873512988589464, 0.8873512988589464, 0.8873512988589464, 0.8873512988589464, 0.8873512988589464, 0.8873512988589464, 0.40592376790483126, 0.889752306945119, 0.46211753278290435]
# Average accuracy 0.7969252699645478

# %%
features=['month',  'pdays',
       'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
       'cons.conf.idx', 'euribor3m', 'nr.employed', 'y']
df=df[features]
df
# Out:
#       month  pdays  previous  ... euribor3m  nr.employed    y
# 0       may    999         0  ...     4.857       5191.0   no
# 1       may    999         0  ...     4.857       5191.0   no
# 2       may    999         0  ...     4.857       5191.0   no
# 3       may    999         0  ...     4.857       5191.0   no
# 4       may    999         0  ...     4.857       5191.0   no
# ...     ...    ...       ...  ...       ...          ...  ...
# 41183   nov    999         0  ...     1.028       4963.6  yes
# 41184   nov    999         0  ...     1.028       4963.6   no
# 41185   nov    999         0  ...     1.028       4963.6   no
# 41186   nov    999         0  ...     1.028       4963.6  yes
# 41187   nov    999         1  ...     1.028       4963.6   no
#
# [41188 rows x 10 columns]

# %%
from sklearn.preprocessing import LabelEncoder

df[["month"]]=df[["month"]].apply(LabelEncoder().fit_transform)
df[["poutcome"]]=df[["poutcome"]].apply(LabelEncoder().fit_transform)
df[["y"]]=df[["y"]].apply(LabelEncoder().fit_transform)

X=df.iloc[:,0:9]
y=df.iloc[:,-1]
df
# Out:
#        month  pdays  previous  ...  euribor3m  nr.employed  y
# 0          6    999         0  ...      4.857       5191.0  0
# 1          6    999         0  ...      4.857       5191.0  0
# 2          6    999         0  ...      4.857       5191.0  0
# 3          6    999         0  ...      4.857       5191.0  0
# 4          6    999         0  ...      4.857       5191.0  0
# ...      ...    ...       ...  ...        ...          ... ..
# 41183      7    999         0  ...      1.028       4963.6  1
# 41184      7    999         0  ...      1.028       4963.6  0
# 41185      7    999         0  ...      1.028       4963.6  0
# 41186      7    999         0  ...      1.028       4963.6  1
# 41187      7    999         1  ...      1.028       4963.6  0
#
# [41188 rows x 10 columns]

# %%
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import StratifiedKFold, KFold

clf = ExtraTreesClassifier(n_estimators=100, max_depth=4)
skf = StratifiedKFold(n_splits=10)
score=[]
for train, test in skf.split(X, y):
  #print('train -  {}   |   test -  {}'.format(np.bincount(y_df[train]), np.bincount(y_df[test])))
  clf.fit(X.iloc[train],y.iloc[train])
  score.append(clf.score(X.iloc[test],y.iloc[test]))
  y_pred=clf.predict(X.iloc[test])
print(score)
print('Average accuracy', np.mean(score))
# Out:
# [0.8873512988589464, 0.8873512988589464, 0.8873512988589464, 0.8873512988589464, 0.8873512988589464, 0.8890507404709881, 0.8873512988589464, 0.4146637533381889, 0.9366197183098591, 0.33098591549295775]
# Average accuracy 0.7895427920765672

# %%
import matplotlib
import matplotlib.pyplot as plt

importances = clf.feature_importances_
std = np.std([tree.feature_importances_ for tree in clf.estimators_], axis=0)
indices = np.argsort(importances)[::-1]

print("Feature ranking:") 
for f in range(X.shape[1]):
  print("%d. %s (%f)" % (f + 1, features[indices[f]], importances[indices[f]]))
# Plot the feature importances of the forest
fig = plt.figure() 
plt.title("Feature importances") 
plt.bar(range(X.shape[1]), importances[indices], color="r", yerr=std[indices], align="center") 
plt.xticks(range(X.shape[1]), np.array(features)[indices]) 
plt.xlim([-1, X.shape[1]]) 
fig.set_size_inches(15, 8) 
axes = plt.gca() 
axes.set_ylim([0, None])
# Out:
# Feature ranking:
# 1. nr.employed (0.253656)
# 2. euribor3m (0.217114)
# 3. emp.var.rate (0.167273)
# 4. pdays (0.114893)
# 5. cons.price.idx (0.102215)
# 6. cons.conf.idx (0.096522)
# 7. poutcome (0.031801)
# 8. month (0.011085)
# 9. previous (0.005440)
# (0, 0.5732036469146329)

# %%
import itertools
def plot_confusion_matrix(cm, classes,

                          normalize=False,

                          title='Confusion matrix',

                          cmap=plt.cm.Blues):

    """

    This function prints and plots the confusion matrix.

    Normalization can be applied by setting `normalize=True`.

    """

    if normalize:

        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

        print("Normalized confusion matrix")

    else:

        print('Confusion matrix, without normalization')

    plt.imshow(cm, interpolation='nearest', cmap=cmap)

    plt.title(title)

    plt.colorbar()

    tick_marks = np.arange(len(classes))

    plt.xticks(tick_marks, classes, rotation=45)

    plt.yticks(tick_marks, classes)

    thresh = cm.max() / 2.

    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):

        t = "(%.2f)"%(cm[i, j])

    plt.tight_layout()

    plt.ylabel('True label')

    plt.xlabel('Predicted label')

# %%
# Compute confusion matrix
y_pred = clf.predict(X)
cnf_matrix = confusion_matrix(y, y_pred)
np.set_printoptions(precision=2)
# Plot non-normalized confusion matrix 
plt.figure() 
plot_confusion_matrix(cnf_matrix, classes=range(len(set(y))), normalize = False, title='Confusion matrix')
# Out:
# Confusion matrix, without normalization
