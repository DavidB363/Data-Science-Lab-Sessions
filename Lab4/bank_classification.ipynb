# %% [markdown]
# <a href="https://colab.research.google.com/github/DavidB363/file-store/blob/master/Lab4/bank_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('https://raw.githubusercontent.com/albanda/CE888/master/lab4/bank-additional-full.csv', delimiter = ";")

df.head()
# Out:
#    age        job  marital  ... euribor3m nr.employed   y
# 0   56  housemaid  married  ...     4.857      5191.0  no
# 1   57   services  married  ...     4.857      5191.0  no
# 2   37   services  married  ...     4.857      5191.0  no
# 3   40     admin.  married  ...     4.857      5191.0  no
# 4   56   services  married  ...     4.857      5191.0  no
#
# [5 rows x 21 columns]

# %%
df_dummies = pd.get_dummies(df)
df_dummies
# Out:
#        age  duration  campaign  ...  poutcome_success  y_no  y_yes
# 0       56       261         1  ...                 0     1      0
# 1       57       149         1  ...                 0     1      0
# 2       37       226         1  ...                 0     1      0
# 3       40       151         1  ...                 0     1      0
# 4       56       307         1  ...                 0     1      0
# ...    ...       ...       ...  ...               ...   ...    ...
# 41183   73       334         1  ...                 0     0      1
# 41184   46       383         1  ...                 0     1      0
# 41185   56       189         2  ...                 0     1      0
# 41186   44       442         1  ...                 0     0      1
# 41187   74       239         3  ...                 0     1      0
#
# [41188 rows x 65 columns]

# %%
del df_dummies["y_no"]
del df_dummies["duration"]

# %%
df_dummies
# Out:
#        age  campaign  pdays  ...  poutcome_nonexistent  poutcome_success  y_yes
# 0       56         1    999  ...                     1                 0      0
# 1       57         1    999  ...                     1                 0      0
# 2       37         1    999  ...                     1                 0      0
# 3       40         1    999  ...                     1                 0      0
# 4       56         1    999  ...                     1                 0      0
# ...    ...       ...    ...  ...                   ...               ...    ...
# 41183   73         1    999  ...                     1                 0      1
# 41184   46         1    999  ...                     1                 0      0
# 41185   56         2    999  ...                     1                 0      0
# 41186   44         1    999  ...                     1                 0      1
# 41187   74         3    999  ...                     0                 0      0
#
# [41188 rows x 63 columns]

# %%
df_dummies['y_yes'].plot.hist()

# %%
X_df=df_dummies.iloc[:, :-1]
X_df
# Out:
#        age  campaign  ...  poutcome_nonexistent  poutcome_success
# 0       56         1  ...                     1                 0
# 1       57         1  ...                     1                 0
# 2       37         1  ...                     1                 0
# 3       40         1  ...                     1                 0
# 4       56         1  ...                     1                 0
# ...    ...       ...  ...                   ...               ...
# 41183   73         1  ...                     1                 0
# 41184   46         1  ...                     1                 0
# 41185   56         2  ...                     1                 0
# 41186   44         1  ...                     1                 0
# 41187   74         3  ...                     0                 0
#
# [41188 rows x 62 columns]

# %%
y_df=df_dummies.iloc[:, -1]
y_df
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 41183    1
# 41184    0
# 41185    0
# 41186    1
# 41187    0
# Name: y_yes, Length: 41188, dtype: uint8

# %%
# Convert dataframes to arrays.
X=X_df.values
y=y_df.values

# %%
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import StratifiedKFold, KFold

clf = ExtraTreesClassifier(n_estimators=100, max_depth=4)
skf = StratifiedKFold(n_splits=10)
score=[]
for train, test in skf.split(X_df, y_df):
  #print('train -  {}   |   test -  {}'.format(np.bincount(y_df[train]), np.bincount(y_df[test])))
  clf.fit(X[train],y[train])
  score.append(clf.score(X[test],y[test]))
  y_pred=clf.predict(X[test])
print(score)
print('Average accuracy', np.mean(score))
# Out:
# [0.8873512988589464, 0.8873512988589464, 0.8873512988589464, 0.8873512988589464, 0.8873512988589464, 0.887836853605244, 0.8873512988589464, 0.56494294731731, 0.8882952889752307, 0.532540067994172]
# Average accuracy 0.8197722951045634

# %%
features = df_dummies.columns

# %%
import matplotlib
import matplotlib.pyplot as plt

importances = clf.feature_importances_
std = np.std([tree.feature_importances_ for tree in clf.estimators_], axis=0)
indices = np.argsort(importances)[::-1]

print("Feature ranking:") 
for f in range(X.shape[1]):
  print("%d. %s (%f)" % (f + 1, features[indices[f]], importances[indices[f]]))
# Plot the feature importances of the forest
fig = plt.figure() 
plt.title("Feature importances") 
plt.bar(range(X.shape[1]), importances[indices], color="r", yerr=std[indices], align="center") 
plt.xticks(range(X.shape[1]), np.array(features)[indices]) 
plt.xlim([-1, X.shape[1]]) 
fig.set_size_inches(15, 8) 
axes = plt.gca() 
axes.set_ylim([0, None])
# Out:
# Feature ranking:
# 1. nr.employed (0.160299)
# 2. emp.var.rate (0.151170)
# 3. pdays (0.114699)
# 4. euribor3m (0.111229)
# 5. cons.conf.idx (0.094898)
# 6. poutcome_success (0.081472)
# 7. cons.price.idx (0.069857)
# 8. month_jun (0.023777)
# 9. month_oct (0.022259)
# 10. poutcome_nonexistent (0.017078)
# 11. contact_cellular (0.016481)
# 12. month_aug (0.016070)
# 13. previous (0.015927)
# 14. month_mar (0.015030)
# 15. contact_telephone (0.011214)
# 16. month_sep (0.010956)
# 17. month_may (0.010469)
# 18. age (0.009302)
# 19. month_dec (0.008702)
# 20. default_no (0.006267)
# 21. job_student (0.005031)
# 22. poutcome_failure (0.004718)
# 23. month_jul (0.004707)
# 24. default_unknown (0.003779)
# 25. job_blue-collar (0.003284)
# 26. job_retired (0.003218)
# 27. month_nov (0.002910)
# 28. month_apr (0.001860)
# 29. marital_single (0.000626)
# 30. campaign (0.000524)
# 31. education_university.degree (0.000487)
# 32. education_basic.9y (0.000415)
# 33. day_of_week_wed (0.000277)
# 34. job_entrepreneur (0.000170)
# 35. day_of_week_mon (0.000137)
# 36. marital_married (0.000116)
# 37. loan_yes (0.000075)
# 38. job_services (0.000050)
# 39. job_unknown (0.000045)
# 40. education_unknown (0.000044)
# 41. job_management (0.000039)
# 42. education_basic.6y (0.000038)
# 43. education_professional.course (0.000036)
# 44. housing_yes (0.000031)
# 45. marital_unknown (0.000029)
# 46. job_technician (0.000021)
# 47. job_self-employed (0.000021)
# 48. job_housemaid (0.000020)
# 49. loan_no (0.000020)
# 50. job_admin. (0.000017)
# 51. housing_no (0.000017)
# 52. day_of_week_thu (0.000017)
# 53. education_high.school (0.000016)
# 54. education_basic.4y (0.000015)
# 55. loan_unknown (0.000013)
# 56. day_of_week_tue (0.000007)
# 57. day_of_week_fri (0.000006)
# 58. housing_unknown (0.000004)
# 59. job_unemployed (0.000003)
# 60. marital_divorced (0.000001)
# 61. education_illiterate (0.000000)
# 62. default_yes (0.000000)
# (0, 0.4322449731712973)

# %%
import pylab as pl

# Compute confusion matrix 
from sklearn.metrics import confusion_matrix, plot_confusion_matrix
y_pred = clf.predict(X) 
cnf_matrix = confusion_matrix(y, y_pred) 
#print(cnf_matrix)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix 
plt.figure() 
#plot_confusion_matrix(cnf_matrix, classes=range(len(set(y))), normalize = False, title='Confusion matrix')
pl.matshow(cnf_matrix)
pl.title('Confusion matrix of the classifier')
pl.colorbar()
pl.show()
